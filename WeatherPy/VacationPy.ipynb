# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# !pip install bokeh hvplot
# !pip install Cartopy
# !pip install geoviews
# !pip install pyproj
import hvplot.pandas
import holoviews as hv
hv.extension('bokeh')
# Out:
# Requirement already satisfied: bokeh in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (3.4.1)
# Requirement already satisfied: hvplot in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (0.10.0)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from bokeh) (3.1.4)
# Requirement already satisfied: contourpy>=1.2 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from bokeh) (1.2.0)
# Requirement already satisfied: numpy>=1.16 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from bokeh) (1.26.4)
# Requirement already satisfied: packaging>=16.8 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from bokeh) (23.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from bokeh) (2.2.2)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from bokeh) (10.3.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from bokeh) (6.0.1)
# Requirement already satisfied: tornado>=6.2 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from bokeh) (6.4.1)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from bokeh) (2022.9.0)
# Requirement already satisfied: colorcet>=2 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from hvplot) (3.1.0)
# Requirement already satisfied: holoviews>=1.11.0 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from hvplot) (1.19.0)
# Requirement already satisfied: panel>=0.11.0 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from hvplot) (1.4.4)
# Requirement already satisfied: param<3.0,>=1.12.0 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from hvplot) (2.1.0)
# Requirement already satisfied: pyviz-comms>=2.1 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from holoviews>=1.11.0->hvplot) (3.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from Jinja2>=2.9->bokeh) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from pandas>=1.2->bokeh) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from pandas>=1.2->bokeh) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from pandas>=1.2->bokeh) (2023.3)
# Requirement already satisfied: markdown in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from panel>=0.11.0->hvplot) (3.4.1)
# Requirement already satisfied: markdown-it-py in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from panel>=0.11.0->hvplot) (2.2.0)
# Requirement already satisfied: linkify-it-py in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from panel>=0.11.0->hvplot) (2.0.0)
# Requirement already satisfied: mdit-py-plugins in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from panel>=0.11.0->hvplot) (0.3.0)
# Requirement already satisfied: requests in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from panel>=0.11.0->hvplot) (2.32.2)
# Requirement already satisfied: tqdm>=4.48.0 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from panel>=0.11.0->hvplot) (4.66.4)
# Requirement already satisfied: bleach in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from panel>=0.11.0->hvplot) (4.1.0)
# Requirement already satisfied: typing-extensions in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from panel>=0.11.0->hvplot) (4.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.2->bokeh) (1.16.0)
# Requirement already satisfied: colorama in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from tqdm>=4.48.0->panel>=0.11.0->hvplot) (0.4.6)
# Requirement already satisfied: webencodings in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from bleach->panel>=0.11.0->hvplot) (0.5.1)
# Requirement already satisfied: uc-micro-py in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from linkify-it-py->panel>=0.11.0->hvplot) (1.0.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from markdown-it-py->panel>=0.11.0->hvplot) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from requests->panel>=0.11.0->hvplot) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from requests->panel>=0.11.0->hvplot) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from requests->panel>=0.11.0->hvplot) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from requests->panel>=0.11.0->hvplot) (2024.6.2)
# Requirement already satisfied: Cartopy in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (0.23.0)
# Requirement already satisfied: numpy>=1.21 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from Cartopy) (1.26.4)
# Requirement already satisfied: matplotlib>=3.5 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from Cartopy) (3.8.4)
# Requirement already satisfied: shapely>=1.7 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from Cartopy) (2.0.5)
# Requirement already satisfied: packaging>=20 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from Cartopy) (23.2)
# Requirement already satisfied: pyshp>=2.3 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from Cartopy) (2.3.1)
# Requirement already satisfied: pyproj>=3.3.1 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from Cartopy) (3.6.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from matplotlib>=3.5->Cartopy) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from matplotlib>=3.5->Cartopy) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from matplotlib>=3.5->Cartopy) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from matplotlib>=3.5->Cartopy) (1.4.4)
# Requirement already satisfied: pillow>=8 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from matplotlib>=3.5->Cartopy) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from matplotlib>=3.5->Cartopy) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from matplotlib>=3.5->Cartopy) (2.9.0.post0)
# Requirement already satisfied: certifi in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from pyproj>=3.3.1->Cartopy) (2024.6.2)
# Requirement already satisfied: six>=1.5 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.5->Cartopy) (1.16.0)
# Requirement already satisfied: geoviews in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (1.12.0)
# Requirement already satisfied: bokeh<3.5.0,>=3.4.0 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from geoviews) (3.4.1)
# Requirement already satisfied: cartopy>=0.18.0 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from geoviews) (0.23.0)
# Requirement already satisfied: holoviews>=1.16.0 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from geoviews) (1.19.0)
# Requirement already satisfied: packaging in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from geoviews) (23.2)
# Requirement already satisfied: numpy in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from geoviews) (1.26.4)
# Requirement already satisfied: shapely in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from geoviews) (2.0.5)
# Requirement already satisfied: param in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from geoviews) (2.1.0)
# Requirement already satisfied: panel>=1.0.0 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from geoviews) (1.4.4)
# Requirement already satisfied: pyproj in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from geoviews) (3.6.1)
# Requirement already satisfied: xyzservices in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from geoviews) (2022.9.0)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from bokeh<3.5.0,>=3.4.0->geoviews) (3.1.4)
# Requirement already satisfied: contourpy>=1.2 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from bokeh<3.5.0,>=3.4.0->geoviews) (1.2.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from bokeh<3.5.0,>=3.4.0->geoviews) (2.2.2)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from bokeh<3.5.0,>=3.4.0->geoviews) (10.3.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from bokeh<3.5.0,>=3.4.0->geoviews) (6.0.1)
# Requirement already satisfied: tornado>=6.2 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from bokeh<3.5.0,>=3.4.0->geoviews) (6.4.1)
# Requirement already satisfied: matplotlib>=3.5 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from cartopy>=0.18.0->geoviews) (3.8.4)
# Requirement already satisfied: pyshp>=2.3 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from cartopy>=0.18.0->geoviews) (2.3.1)
# Requirement already satisfied: colorcet in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from holoviews>=1.16.0->geoviews) (3.1.0)
# Requirement already satisfied: pyviz-comms>=2.1 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from holoviews>=1.16.0->geoviews) (3.0.2)
# Requirement already satisfied: markdown in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from panel>=1.0.0->geoviews) (3.4.1)
# Requirement already satisfied: markdown-it-py in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from panel>=1.0.0->geoviews) (2.2.0)
# Requirement already satisfied: linkify-it-py in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from panel>=1.0.0->geoviews) (2.0.0)
# Requirement already satisfied: mdit-py-plugins in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from panel>=1.0.0->geoviews) (0.3.0)
# Requirement already satisfied: requests in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from panel>=1.0.0->geoviews) (2.32.2)
# Requirement already satisfied: tqdm>=4.48.0 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from panel>=1.0.0->geoviews) (4.66.4)
# Requirement already satisfied: bleach in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from panel>=1.0.0->geoviews) (4.1.0)
# Requirement already satisfied: typing-extensions in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from panel>=1.0.0->geoviews) (4.11.0)
# Requirement already satisfied: certifi in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from pyproj->geoviews) (2024.6.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from Jinja2>=2.9->bokeh<3.5.0,>=3.4.0->geoviews) (2.1.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from matplotlib>=3.5->cartopy>=0.18.0->geoviews) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from matplotlib>=3.5->cartopy>=0.18.0->geoviews) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from matplotlib>=3.5->cartopy>=0.18.0->geoviews) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from matplotlib>=3.5->cartopy>=0.18.0->geoviews) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from matplotlib>=3.5->cartopy>=0.18.0->geoviews) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from pandas>=1.2->bokeh<3.5.0,>=3.4.0->geoviews) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from pandas>=1.2->bokeh<3.5.0,>=3.4.0->geoviews) (2023.3)
# Requirement already satisfied: colorama in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from tqdm>=4.48.0->panel>=1.0.0->geoviews) (0.4.6)
# Requirement already satisfied: six>=1.9.0 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from bleach->panel>=1.0.0->geoviews) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from bleach->panel>=1.0.0->geoviews) (0.5.1)
# Requirement already satisfied: uc-micro-py in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from linkify-it-py->panel>=1.0.0->geoviews) (1.0.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from markdown-it-py->panel>=1.0.0->geoviews) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from requests->panel>=1.0.0->geoviews) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from requests->panel>=1.0.0->geoviews) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from requests->panel>=1.0.0->geoviews) (2.2.2)
# Requirement already satisfied: pyproj in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (3.6.1)
# Requirement already satisfied: certifi in c:\users\anupreet virk\.anaconda\new folder\new folder\lib\site-packages (from pyproj) (2024.6.2)
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1185'>
#   <div id="be983079-a7f7-4148-8f6e-b28a75cd3b47" data-root-id="p1185" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"561c05f6-ee4a-4ad0-bca9-0a46d5ef50cd":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1185"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1186","attributes":{"plot_id":"p1185","comm_id":"a849d142d1234599b3ff7af1243ef2cf","client_comm_id":"d2834fde05fe4d86899d71c4fd190079"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"A ...
#   var render_items = [{"docid":"561c05f6-ee4a-4ad0-bca9-0a46d5ef50cd","roots":{"p1185":"be983079-a7f7-4148-8f6e-b28a75cd3b47"},"root_ids":["p1185"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests


# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID         City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0    adamstown -25.0660 -130.1015    295.59        84         100
# 1        1  olonkinbyen  70.9221   -8.7187    278.91        99          99
# 2        2        mugia  43.1041   -9.2179    294.35        91          43
# 3        3       kodiak  57.7900 -152.4072    288.88        51           0
# 4        4    greenland  43.0362  -70.8328    299.98        76          75
#
#    Wind Speed Country        Date
# 0       11.43      PN  1722447631
# 1        2.90      SJ  1722447687
# 2        1.83      ES  1722447688
# 3        8.75      US  1722447689
# 4        4.12      US  1722447690

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot= city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo=True,
    tiles="OSM",
    frame_width=700,
    frame_height=500,
    size="Humidity",
    scale=0.9,
    color="City"
    
)


# Display the map
map_plot
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values

# Define the ideal weather conditions
min_temp = 290  # 17°C in Kelvin
max_temp = 300  # 27°C in Kelvin
max_humidity = 60  # Maximum humidity percentage
max_cloudiness = 55  # Maximum cloudiness percentage
max_wind_speed = 7  # Maximum wind speed in m/s

# Filter cities that fit the criteria
ideal_weather_df = city_data_df[
    (city_data_df["Max Temp"] >= min_temp) &
    (city_data_df["Max Temp"] <= max_temp) &
    (city_data_df["Humidity"] <= max_humidity) &
    (city_data_df["Cloudiness"] <= max_cloudiness) &
    (city_data_df["Wind Speed"] <= max_wind_speed)
]

# Drop any rows with null values
ideal_weather_df = ideal_weather_df.dropna()

# Display sample data
ideal_weather_df.head(20)
# Out:
#      City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 24        24          albertina -22.2008  -46.6158    299.86        29
# 48        48           thompson  55.7435  -97.8558    296.24        49
# 78        78            klyuchi  52.2667   79.1667    296.50        51
# 85        85          al hamra'  32.4406   36.1512    299.72        51
# 114      114         isafjordur  66.0755  -23.1240    290.17        48
# 144      144            kurchum  48.5722   83.6542    293.92        49
# 148      148          klyavlino  54.2649   52.0267    291.64        56
# 150      150             shpola  49.0069   31.3947    294.58        38
# 174      174            talnakh  69.4865   88.3972    291.95        42
# 175      175              sucre -19.0333  -65.2627    293.03        36
# 260      260           chicoana -25.1009  -65.5331    295.40        24
# 263      263               leua  48.2156   18.6071    299.58        31
# 285      285         uacu cungo -11.3634   15.1208    294.96        46
# 291      291             bukama  -9.2000   25.8500    299.58        17
# 299      299            sechura  -5.5569  -80.8222    297.35        59
# 300      300  guadalupe y calvo  26.1000 -106.9667    296.52        50
# 328      328   minas de marcona -15.2119  -75.1103    291.94        52
# 338      338          flin flon  54.7682 -101.8650    299.06        38
# 340      340      fort mcmurray  56.7268 -111.3810    297.92        50
# 344      344            atbasar  51.8000   68.3333    297.40        43
#
#      Cloudiness  Wind Speed Country        Date
# 24            7        2.67      BR  1722447719
# 48           20        5.14      CA  1722447746
# 78            8        2.48      RU  1722447663
# 85            0        3.96      JO  1722447797
# 114          40        6.69      IS  1722447630
# 144           0        4.17      KZ  1722447867
# 148          53        1.34      RU  1722447872
# 150           2        3.97      UA  1722447874
# 174           5        2.03      RU  1722447901
# 175           4        5.22      BO  1722447902
# 260          41        2.61      AR  1722448005
# 263          35        0.93      SK  1722448009
# 285           7        2.35      AO  1722448036
# 291           0        1.65      CD  1722448044
# 299          23        6.63      PE  1722448053
# 300           1        3.10      MX  1722448055
# 328          23        2.91      PE  1722448091
# 338           0        3.60      CA  1722447837
# 340           0        5.66      CA  1722448030
# 344          51        1.70      KZ  1722448111

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_weather_df[["City", "Country", "Lat", "Lng", "Humidity"]].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"]=" "

# Display sample data
hotel_df.head(15)
# Out:
#            City Country      Lat      Lng  Humidity Hotel Name
# 24    albertina      BR -22.2008 -46.6158        29
# 48     thompson      CA  55.7435 -97.8558        49
# 78      klyuchi      RU  52.2667  79.1667        51
# 85    al hamra'      JO  32.4406  36.1512        51
# 114  isafjordur      IS  66.0755 -23.1240        48
# 144     kurchum      KZ  48.5722  83.6542        49
# 148   klyavlino      RU  54.2649  52.0267        56
# 150      shpola      UA  49.0069  31.3947        38
# 174     talnakh      RU  69.4865  88.3972        42
# 175       sucre      BO -19.0333 -65.2627        36
# 260    chicoana      AR -25.1009 -65.5331        24
# 263        leua      SK  48.2156  18.6071        31
# 285  uacu cungo      AO -11.3634  15.1208        46
# 291      bukama      CD  -9.2000  25.8500        17
# 299     sechura      PE  -5.5569 -80.8222        59

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "limit":15,
    "categories":"accommodation.hotel",
    "api_key": geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    lat = row["Lat"]
    lng = row["Lng"]
   

    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lng},{lat},{radius}"
    params["bias"] = f"proximity:{lng},{lat}"

    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make and API request using the params dictionary
    name_address = requests.get(base_url, params=params)
    # Convert the API response to JSON format
    name_address = name_address.json()

    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"

    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# albertina - nearest hotel: Hotel Parque das Primaveras
# thompson - nearest hotel: Thompson Inn
# klyuchi - nearest hotel: No hotel found
# al hamra' - nearest hotel: No hotel found
# isafjordur - nearest hotel: Hótel Horn
# kurchum - nearest hotel: No hotel found
# klyavlino - nearest hotel: No hotel found
# shpola - nearest hotel: No hotel found
# talnakh - nearest hotel: Талнах
# sucre - nearest hotel: El Gobernador Hostal
# chicoana - nearest hotel: Hostal Los Faroles
# leua - nearest hotel: Levi Dom
# uacu cungo - nearest hotel: Ritz Waku Kungu
# bukama - nearest hotel: Mission catholique
# sechura - nearest hotel: Maximus Inn
# guadalupe y calvo - nearest hotel: No hotel found
# minas de marcona - nearest hotel: No hotel found
# flin flon - nearest hotel: Copperbelt Hotel
# fort mcmurray - nearest hotel: Nomad Hotel and Suites
# atbasar - nearest hotel: Дана
# altay - nearest hotel: Sunshine Holiday Hotel
# divicani - nearest hotel: Hotel Stari Grad
# constantia - nearest hotel: Hotel Dali
# lompoc - nearest hotel: Red Roof Inn Lompoc
# komsomol'sk - nearest hotel: Славутич
# burley - nearest hotel: Hampton Inn & Suites
# mammoth lakes - nearest hotel: Travelodge Mammoth Lakes
# rakops - nearest hotel: Rakops River Lodge
# kununurra - nearest hotel: No hotel found
# la ronge - nearest hotel: La Ronge Hotel and Suites
# chilecito - nearest hotel: Hermosina Hotel
# astrakhan - nearest hotel: Omega
#                   City Country      Lat       Lng  Humidity  \
# 24           albertina      BR -22.2008  -46.6158        29
# 48            thompson      CA  55.7435  -97.8558        49
# 78             klyuchi      RU  52.2667   79.1667        51
# 85           al hamra'      JO  32.4406   36.1512        51
# 114         isafjordur      IS  66.0755  -23.1240        48
# 144            kurchum      KZ  48.5722   83.6542        49
# 148          klyavlino      RU  54.2649   52.0267        56
# 150             shpola      UA  49.0069   31.3947        38
# 174            talnakh      RU  69.4865   88.3972        42
# 175              sucre      BO -19.0333  -65.2627        36
# 260           chicoana      AR -25.1009  -65.5331        24
# 263               leua      SK  48.2156   18.6071        31
# 285         uacu cungo      AO -11.3634   15.1208        46
# 291             bukama      CD  -9.2000   25.8500        17
# 299            sechura      PE  -5.5569  -80.8222        59
# 300  guadalupe y calvo      MX  26.1000 -106.9667        50
# 328   minas de marcona      PE -15.2119  -75.1103        52
# 338          flin flon      CA  54.7682 -101.8650        38
# 340      fort mcmurray      CA  56.7268 -111.3810        50
# 344            atbasar      KZ  51.8000   68.3333        43
# 365              altay      CN  47.8667   88.1167        41
# 372           divicani      BA  44.3667   17.3261        52
# 375         constantia      RO  44.1833   28.6500        56
# 378             lompoc      US  34.6391 -120.4579        51
# 381        komsomol'sk      UA  49.0097   33.6455        44
# 431             burley      US  42.5357 -113.7928        49
# 461      mammoth lakes      US  37.6485 -118.9721        21
# 475             rakops      BW -21.0167   24.3333        15
# 489          kununurra      AU -15.7667  128.7333        32
# 510           la ronge      CA  55.1001 -105.2842        44
# 532          chilecito      AR -29.1619  -67.4974        14
# 547          astrakhan      RU  46.3497   48.0408        41
#
#                       Hotel Name
# 24   Hotel Parque das Primaveras
# 48                  Thompson Inn
# 78                No hotel found
# 85                No hotel found
# 114                   Hótel Horn
# 144               No hotel found
# 148               No hotel found
# 150               No hotel found
# 174                       Талнах
# 175         El Gobernador Hostal
# 260           Hostal Los Faroles
# 263                     Levi Dom
# 285              Ritz Waku Kungu
# 291           Mission catholique
# 299                  Maximus Inn
# 300               No hotel found
# 328               No hotel found
# 338             Copperbelt Hotel
# 340       Nomad Hotel and Suites
# 344                         Дана
# 365       Sunshine Holiday Hotel
# 372             Hotel Stari Grad
# 375                   Hotel Dali
# 378          Red Roof Inn Lompoc
# 381                     Славутич
# 431         Hampton Inn & Suites
# 461     Travelodge Mammoth Lakes
# 475           Rakops River Lodge
# 489               No hotel found
# 510    La Ronge Hotel and Suites
# 532              Hermosina Hotel
# 547                        Omega

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_1=hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo=True,
    tiles="OSM",
    frame_width=700,
    frame_height=500,
    size="Humidity",
    scale=0.9,
    color="City",
    hover_cols=["Hotel Name","Country"]
    
    
)

# Display the map
map_plot_1
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
